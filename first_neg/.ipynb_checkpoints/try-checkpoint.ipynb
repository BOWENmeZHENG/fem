# %%
# !pip install pygmsh
# !pip install solidspy
# !pip install easygui
# !pip install meshio

# %%
import pygmsh
import matplotlib.pyplot as plt
from solidspy import solids_GUI 
import pandas as pd

# %% [markdown]
# # Generate mesh

# %% [markdown]
# ## load geometry

# %%
points = pd.read_csv("points.csv")

# %%
plt.figure(figsize=(8,8))
plt.scatter(points.x, points.y)
plt.show()

# %% [markdown]
# ## read parts

# %%
pt1 = pd.read_csv("pt1.csv")
pt2 = pd.read_csv("pt2.csv")
plt.figure(figsize=(8,8))
plt.plot(pt1.x, pt1.y)
plt.plot(pt2.x, pt2.y)
plt.show()

# %%
with pygmsh.geo.Geometry() as geom:
    geom.add_polygon(
        pt1.values,
        mesh_size=0.1
    )
    geom.add_polygon(
        pt2.values,
        mesh_size=0.1
    )
    mesh = geom.generate_mesh()
mesh_pts = mesh.points

# %%
plt.figure(figsize=(8,8))
plt.scatter(mesh_pts[:,0], mesh_pts[:,1])
plt.show()

# %% [markdown]
# # Write input files

# %% [markdown]
# ## 1. Write nodes.txt
# - Column 0: Nodal identifier (integer).
# - Column 1: x-coordinate (float).
# - Column 2: y-coordinate (float).
# - Column 3: Boundary condition flag along the x-direction (0 free, -1 restrained).
# - Column 4: Boundary condition flag along the y-direction (0 free, -1 restrained).
#
# ```
# 0  0.00  0.00   0  -1
# 1  2.00  0.00   0  -1
# 2  2.00  2.00   0   0
# 3  0.00  2.00   0   0
# 4  1.00  0.00  -1  -1
# 5  2.00  1.00   0   0
# 6  1.00  2.00   0   0
# 7  0.00  1.00   0   0
# 8  1.00  1.00   0   0
# ```

# %%
# fix bottom
with open('nodes.txt', 'w') as f_nodes:
    for i, point in enumerate(mesh_pts):
        if point[1] == min(mesh_pts[:, 1]):
            bc_x, bc_y = -1, -1
        else:
            bc_x, bc_y = 0, 0
        f_nodes.write(f"{i:4} {point[0]:8.4f} {point[1]:8.4f}  {bc_x:4}  {bc_y:4} \n")

# %% [markdown]
# ## 2. Write eles.txt
# - Column 0: Element identifier (integer).
# - Column 1: Element type (integer):
#     - 1 for a 4-noded quadrilateral.
#     - 2 for a 6-noded triangle.
#     - 3 for a 3-noded triangle.
# - Column 2: Material profile for the current element (integer).
# - Column 3 to end: Element connectivity, this is a list of the nodes conforming each element. The nodes should be listed in **counterclockwise** orientation.
#
# ```
# 0   1   0   0   4   8   7
# 1   1   0   4   1   5   8
# 2   1   0   7   8   6   3
# 3   1   0   8   5   2   6
# ```

# %%
elements = mesh.cells_dict['triangle']
with open('eles.txt', 'w') as f_eles:
    for i, element in enumerate(elements):
        f_eles.write(f"{i:4}   3   0  {element[0]:4} {element[1]:4}  {element[2]:4} \n")

# %% [markdown]
# ## 3. mater.txt
# - Column 0: Young’s modulus for the current profile (float).
# - Column 1: Poisson’s ratio for the current profile (float).
# ```
# 1.0  0.3
# ```

# %%
E = 1.0
nu = 0.3
with open('mater.txt', 'w') as f_mater:
    f_mater.write(f"{E:8.4f} {nu:8.4f}")

# %% [markdown]
# ## 4. loads.txt
# - Column 0: Nodal identifier (integer).
# - Column 1: Load magnitude for the current node along the x-direction (float).
# - Column 2: Load magnitude for the current node along the y-direction (float).
# ```
# 3  0.0  1.0
# 6  0.0  2.0
# 2  0.0  1.0
# ```

# %%
# load top
load = -2.0
with open('loads.txt', 'w') as f_loads:
    for i, point in enumerate(mesh_pts):
        if point[1] == max(mesh_pts[:, 1]):
            f_loads.write(f"{i:4} {0.0:8.4f} {load:8.4f} \n")

# %% [markdown]
# # Run FE simulation

# %%
disp = solids_GUI()  # run the Finite Element Analysis
plt.show()    # plot contours
# Out:
# Number of nodes: 827
# Number of elements: 1230
# Number of equations: 1648
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-27b9dfcaf5b6> in <module>
# ----> 1 disp = solids_GUI()  # run the Finite Element Analysis
#       2 plt.show()    # plot contours
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/solids_GUI.py in solids_GUI(plot_contours, compute_strains, folder)
#      70
#      71     # System assembly
# ---> 72     KG = ass.assembler(elements, mats, nodes, neq, DME)
#      73     RHSG = ass.loadasem(loads, IBC, neq)
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/assemutil.py in assembler(elements, mats, nodes, neq, DME, sparse, uel)
#     165     """
#     166     if sparse:
# --> 167         KG = sparse_assem(elements, mats, nodes, neq, DME, uel=uel)
#     168     else:
#     169         KG = dense_assem(elements, mats, nodes, neq, DME, uel=uel)
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/assemutil.py in sparse_assem(elements, mats, nodes, neq, DME, uel)
#     258     nels = elements.shape[0]
#     259     for el in range(nels):
# --> 260         kloc, ndof, iet  = retriever(elements , mats  , nodes , el, uel=uel)
#     261         dme = DME[el, :ndof]
#     262
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/assemutil.py in retriever(elements, mats, nodes, i, uel)
#     123             kloc = ue.uel6ntrian(elcoor, par1, par0)
#     124         elif iet == 3:
# --> 125             kloc = ue.uel3ntrian(elcoor, par1, par0)
#     126         elif iet == 5:
#     127             kloc = ue.uelspring(elcoor, par1, par0)
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/uelutil.py in uel3ntrian(coord, enu, Emod)
#     165         si = XP[i, 1]
#     166         alf = XW[i]
# --> 167         ddet, B = fem.stdm3NT(ri, si, coord)
#     168         kl = kl + 0.5*np.dot(np.dot(B.T,C), B)*alf*ddet
#     169     return kl
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/femutil.py in stdm3NT(r, s, coord)
#     324             [-1, 1, 0],
#     325             [-1, 0, 1]])
# --> 326     det, jaco_inv = jacoper(dhdx, coord)
#     327     dhdx = np.dot(jaco_inv, dhdx)
#     328     B[0, ::2] = dhdx[0, :]
#
# ~/anaconda3/lib/python3.7/site-packages/solidspy/femutil.py in jacoper(dhdx, coord)
#     360     if det < 0.0:
#     361         msg = "Jacobian is negative. Check your elements orientation!"
# --> 362         raise ValueError(msg)
#     363     return det, jaco_inv
#     364
#
# ValueError: Jacobian is negative. Check your elements orientation!
